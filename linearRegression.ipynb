# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df=pd.read_csv("placement.csv")

# %%
plt.scatter(df['cgpa'],df['package'])

# %%
X=df.iloc[:,0:1]
y=df.iloc[:,-1]

# %%
X.head()
# Out:
#    cgpa
# 0  6.89
# 1  5.12
# 2  7.82
# 3  7.42
# 4  6.94

# %%
y.head()
# Out:
# 0    3.26
# 1    1.98
# 2    3.25
# 3    3.67
# 4    3.57
# Name: package, dtype: float64

# %%
from sklearn.model_selection import train_test_split

# %%
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.2,random_state=2)

# %%
from sklearn.linear_model import LinearRegression

# %%
lr=LinearRegression()

# %%
lr.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
X_test
# Out:
#      cgpa
# 112  8.58
# 29   7.15
# 182  5.88
# 199  6.22
# 193  4.57
# 85   4.79
# 10   5.32
# 54   6.86
# 115  8.35
# 35   6.87
# 12   8.94
# 92   7.90
# 13   6.93
# 126  5.91
# 174  7.32
# 2    7.82
# 44   5.09
# 3    7.42
# 113  6.94
# 14   7.73
# 23   6.19
# 25   7.28
# 6    6.73
# 134  7.20
# 165  8.21
# 173  6.75
# 45   7.87
# 65   7.60
# 48   8.63
# 122  5.12
# 178  8.15
# 64   7.36
# 9    8.31
# 57   6.60
# 78   6.59
# 71   7.47
# 128  7.93
# 176  6.29
# 131  6.37
# 53   6.47

# %%
y_test
# Out:
# 112    4.10
# 29     3.49
# 182    2.08
# 199    2.33
# 193    1.94
# 85     1.48
# 10     1.86
# 54     3.09
# 115    4.21
# 35     2.87
# 12     3.65
# 92     4.00
# 13     2.89
# 126    2.60
# 174    2.99
# 2      3.25
# 44     1.86
# 3      3.67
# 113    2.37
# 14     3.42
# 23     2.48
# 25     3.65
# 6      2.60
# 134    2.83
# 165    4.08
# 173    2.56
# 45     3.58
# 65     3.81
# 48     4.09
# 122    2.01
# 178    3.63
# 64     2.92
# 9      3.51
# 57     1.94
# 78     2.21
# 71     3.34
# 128    3.34
# 176    3.23
# 131    2.01
# 53     2.61
# Name: package, dtype: float64

# %%
lr.predict(X_test.iloc[2].values.reshape(1,1))
# Out:
# c:\Users\91996\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([2.38464568])

# %%
plt.scatter(df['cgpa'],df['package'])
plt.plot(X_test,lr.predict(X_test),color='red')
plt.xlabel('CGPA')
plt.ylabel('pacakage in lpa')
# Out:
# Text(0, 0.5, 'pacakage in lpa')

# %%
lr.coef_
# Out:
# array([0.55795197])

# %%
lr.intercept_
# Out:
# np.float64(-0.8961119222429144)

# %%
from sklearn.metrics import mean_absolute_error,mean_squared_error,r2_score

# %%
y_pred=lr.predict(X_test)

# %%
y_pred
# Out:
# array([3.89111601, 3.09324469, 2.38464568, 2.57434935, 1.6537286 ,
#        1.77647803, 2.07219258, 2.93143862, 3.76278706, 2.93701814,
#        4.09197872, 3.51170867, 2.97049525, 2.40138424, 3.18809652,
#        3.46707251, 1.94386362, 3.24389172, 2.97607477, 3.41685683,
#        2.55761079, 3.16577844, 2.85890486, 3.12114229, 3.68467378,
#        2.8700639 , 3.49497011, 3.34432308, 3.91901361, 1.96060218,
#        3.65119666, 3.2104146 , 3.74046898, 2.7863711 , 2.78079158,
#        3.27178932, 3.52844723, 2.61340599, 2.65804215, 2.71383735])

# %%
y_test
# Out:
# 112    4.10
# 29     3.49
# 182    2.08
# 199    2.33
# 193    1.94
# 85     1.48
# 10     1.86
# 54     3.09
# 115    4.21
# 35     2.87
# 12     3.65
# 92     4.00
# 13     2.89
# 126    2.60
# 174    2.99
# 2      3.25
# 44     1.86
# 3      3.67
# 113    2.37
# 14     3.42
# 23     2.48
# 25     3.65
# 6      2.60
# 134    2.83
# 165    4.08
# 173    2.56
# 45     3.58
# 65     3.81
# 48     4.09
# 122    2.01
# 178    3.63
# 64     2.92
# 9      3.51
# 57     1.94
# 78     2.21
# 71     3.34
# 128    3.34
# 176    3.23
# 131    2.01
# 53     2.61
# Name: package, dtype: float64

# %%
print("Mean absolute error",mean_absolute_error(y_test,y_pred))
# Out:
# Mean absolute error 0.2884710931878175

# %%
print("Mean Squared error",mean_squared_error(y_test,y_pred))
# Out:
# Mean Squared error 0.12129235313495527

# %%
print("Root mean squared error",np.sqrt(mean_squared_error(y_test,y_pred)))
# Out:
# Root mean squared error 0.34827051717731616

# %%
print("R2 score",r2_score(y_test,y_pred))
# Out:
# R2 score 0.780730147510384

# %%
r2=r2_score(y_test,y_pred)

# %%
X_test.shape
# Out:
# (40, 1)

# %%
adjusted_r2=1-((1-r2)*(X_test.shape[0]-1)/(X_test.shape[0]-1-1))

# %%
adjusted_r2
# Out:
# 0.7749598882343415

# %%
df2=df.copy()

# %%
df2['random_feature']=np.random.random(200)
df2=df2[['cgpa','random_feature','package']]
df2
# Out:
#      cgpa  random_feature  package
# 0    6.89        0.982988     3.26
# 1    5.12        0.141775     1.98
# 2    7.82        0.084342     3.25
# 3    7.42        0.326522     3.67
# 4    6.94        0.346972     3.57
# ..    ...             ...      ...
# 195  6.93        0.088225     2.46
# 196  5.89        0.991352     2.57
# 197  7.21        0.326011     3.24
# 198  7.63        0.338520     3.96
# 199  6.22        0.632615     2.33
#
# [200 rows x 3 columns]

# %%
X=df2.iloc[:,0:2]
y=df2.iloc[:,-1]

# %%
y
# Out:
# 0      3.26
# 1      1.98
# 2      3.25
# 3      3.67
# 4      3.57
#        ...
# 195    2.46
# 196    2.57
# 197    3.24
# 198    3.96
# 199    2.33
# Name: package, Length: 200, dtype: float64

# %%
plt.scatter(df2['random_feature'],df2['package'])
plt.xlabel('random_feature')
plt.ylabel('pacakage in lpa')
# Out:
# Text(0, 0.5, 'pacakage in lpa')

# %%
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.2,random_state=2)

# %%
lr=LinearRegression()
lr.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred=lr.predict(X_test)

# %%
y_pred
# Out:
# array([3.89346846, 3.09104429, 2.38742246, 2.57506807, 1.6551439 ,
#        1.77635369, 2.07305072, 2.93061506, 3.76232742, 2.93355521,
#        4.09348485, 3.51480747, 2.96787359, 2.40192076, 3.18489006,
#        3.4641616 , 1.94290545, 3.24259656, 2.97450284, 3.41509337,
#        2.55429149, 3.16900212, 2.86120385, 3.11777611, 3.68656189,
#        2.86912521, 3.49218159, 3.34182787, 3.92117477, 1.96181288,
#        3.65021852, 3.21348687, 3.74134412, 2.78469574, 2.78309564,
#        3.26969825, 3.52534373, 2.61033655, 2.65742641, 2.71422232])

# %%
print("R2 score",r2_score(y_test,y_pred))
r2=r2_score(y_test,y_pred)
# Out:
# R2 score 0.7808907566308795

# %%
adjusted_r2=1-((1-r2)*(X_test.shape[0]-1)/(X_test.shape[0]-1-2))
print("adjusted_r2",adjusted_r2)
# Out:
# adjusted_r2 0.7690470137460621

# %%
df3=df.copy()
df3['iq']=df3['package'] + (np.random.randint(-15,15,200)/10)
df3=df3[['cgpa','iq','package']]

# %%
plt.scatter(df3['iq'],df2['package'])
plt.xlabel('iq')
plt.ylabel('pacakage in lpa')
# Out:
# Text(0, 0.5, 'pacakage in lpa')

# %%
X=df3.iloc[:,0:2]
y=df3.iloc[:,-1]

# %%
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.2,random_state=2)

# %%
lr=LinearRegression()
lr.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred=lr.predict(X_test)

# %%
print("R2 score",r2_score(y_test,y_pred))
r2=r2_score(y_test,y_pred)
# Out:
# R2 score 0.8096224760841715

# %%
adjusted_r2=1-((1-r2)*(X_test.shape[0]-1)/(X_test.shape[0]-1-2))
print("adjusted_r2",adjusted_r2)
# Out:
# adjusted_r2 0.7993317991157484
